# %%
# Who developed Python Programming Language
# Python was created by Guido van Rossum

# Which type of Programming does Python support? 
# Python is a multi-paradigm programming language, meaning it supports multiple programming styles. Specifically, Python supports:
#1: Procedural Programming:
#2:Functional Programming (FP):
#3:Object-Oriented Programming (OOP):

# Is Python case sensitive when dealing with identifiers
# Yes, Python is case-sensitive when dealing with identifiers.  This means that variables, functions, classes, etc. 
# with different capitalization are considered distinct entities.

# What is the correct extension of the Python file
# The correct extension for Python source code files is ".py

# Is Python code compiled or interpreted
# Python is both compiled and interpreted
# Compilation:
# When you run a Python program, the source code (.py file) is first compiled into a lower-level representation called bytecode 
# (.pyc or .pyo files).
# Interpretation:
# The Python interpreter then executes the bytecode line by line, translating each instruction into machine code that can be directly
#  executed by the computer's processor.

#Name a few blocks of code used to define in Python language
if x > 5:
  print("x is greater than 5")
else:
  print("x is not greater than 5")
for i in range(5):
  print(i)

# State a character used to give single-line comments in Python
# In Python, the character used to give single-line comments is the hash symbol (#)

# Mention functions which can help us to find the version of python that we are currently working on
# The command python --version or python -V can be used to check the installed Python version on the command line

# Python supports the creation of anonymous functions at runtime, using a construct called
# Python supports the creation of anonymous functions at runtime using a construct called lambda

# What does pip stand for python
# Pip is a recursive acronym for "Preferred Installer Program" or "Pip Installs Packages"

# Mention a few built-in functions in python
# Python comes with a variety of built-in functions that help you perform common tasks. Here are a few examples:
# len(object): Returns the length (number of items) of an object like a string, list, tuple, or dictionary.
# print(object): Outputs the specified object to the console.
# type(object): Returns the type of the specified object.
# int(x): Converts x to an integer.
# float(x): Converts x to a floating-point number.
# str(x): Converts x to a string.
# range(start, stop, step): Generates a sequence of numbers from start (inclusive) to stop (exclusive) with an optional step.

# What is the maximum possible length of an identifier in Python
# An identifier can have a maximum length of 79 characters in Python. 

# What are the benefits of using Python
# Ease of Use and Readability ,Simple Syntax,Clean Code,Versatility and Flexibility etc

# How is memory managed in Python
# Python employs a multifaceted approach to memory management, primarily handled automatically by the Python interpreter, 
# relieving the developer of manual memory allocation and deallocation

# Download Python Installer:

# Visit the official Python website: python.org.
# Navigate to the Downloads section and download the latest version of Python for Windows. Choose either the 64-bit or 32-bit installer based on your system architecture.
# Run the Installer:

# Once downloaded, run the installer executable (.exe file).
# Make sure to check the box that says "Add Python x.x to PATH" during the installation process. This will automatically set the necessary path variables.
# Verify Installation:

# Open a command prompt (CMD) and type python --version. This should display the installed Python version if the installation was successful.
# Setting Path Variables Manually (if not done during installation):
# If you didn't select the option to add Python to PATH during installation or if you need to do it manually:

# Find Python Installation Path:

# Locate the folder where Python is installed. By default, it's usually C:\PythonXX (where XX is the version number).
# Set PATH Variable:

# Right-click on "This PC" or "Computer" on your desktop or in File Explorer, then click on "Properties".
# Click on "Advanced system settings" on the left side.
# In the System Properties window, click on the "Environment Variables..." button.
# In the Environment Variables window, find the PATH variable in the "System variables" section and click on "Edit...".
# Add the path to your Python installation (e.g., C:\PythonXX) to the PATH variable. If there are existing entries, separate them with a 
# semicolon (;).
# Verify Path Variable:

# Open a new command prompt window and type python --version to verify that Python can be called from any directory.
